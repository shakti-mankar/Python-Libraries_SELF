# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# **Pivot Tables**

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

# df = pd.DataFrame(data)

# df['Month'] = df['Date'].dt.month_name()
# df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
# df

df = pd.DataFrame(data)
# Out:
#          Date Product Region  Sales  Units    Rep
# 0  2023-01-01       A   East    276     67   John
# 1  2023-01-02       B   West    698     63   Mary
# 2  2023-01-03       C  North    567     55    Bob
# 3  2023-01-04       D  South    100     81  Alice
# 4  2023-01-05       A   East    274     30   John
# 5  2023-01-06       B   West    682     93   Mary
# 6  2023-01-07       C  North    725     86    Bob
# 7  2023-01-08       D  South    111     12  Alice
# 8  2023-01-09       A   East    974     81   John
# 9  2023-01-10       B   West    505     35   Mary
# 10 2023-01-11       C  North    125     22    Bob
# 11 2023-01-12       D  South    775     39  Alice
# 12 2023-01-13       A   East    845     93   John
# 13 2023-01-14       B   West    959     14   Mary
# 14 2023-01-15       C  North    908     39    Bob
# 15 2023-01-16       D  South    409     58  Alice
# 16 2023-01-17       A   East    853     18   John
# 17 2023-01-18       B   West    118     30   Mary
# 18 2023-01-19       C  North    665     28    Bob
# 19 2023-01-20       D  South    671     61  Alice

# %%
pd.pivot_table(df,values = "Sales" , index="Region" , columns ="Product" , aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     845.0    NaN    NaN    NaN
# North      NaN    NaN  665.0    NaN
# South      NaN    NaN    NaN  409.0
# West       NaN  682.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values = ["Sales" , "Units"] , index = "Region" , columns = "Product" , aggfunc="median" )

pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     845.0    NaN    NaN    NaN  67.0   NaN   NaN   NaN
# North      NaN    NaN  665.0    NaN   NaN   NaN  39.0   NaN
# South      NaN    NaN    NaN  409.0   NaN   NaN   NaN  58.0
# West       NaN  682.0    NaN    NaN   NaN  35.0   NaN   NaN

# %%
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     644.4    NaN    NaN    NaN  57.8   NaN   NaN   NaN
# North      NaN    NaN  598.0    NaN   NaN   NaN  46.0   NaN
# South      NaN    NaN    NaN  413.2   NaN   NaN   NaN  50.2
# West       NaN  592.4    NaN    NaN   NaN  47.0   NaN   NaN

# %%
# pd.pivot_table(df,values = "Sales",index = 'Region',columns="Product",aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     415.0    NaN    NaN    NaN
# North      NaN    NaN  596.0    NaN
# South      NaN    NaN    NaN  626.0
# West       NaN  535.0    NaN    NaN

# %%
# pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
# pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     474.2    NaN    NaN    NaN  38.6   NaN   NaN   NaN
# North      NaN    NaN  617.0    NaN   NaN   NaN  42.0   NaN
# South      NaN    NaN    NaN  485.0   NaN   NaN   NaN  64.4
# West       NaN  527.2    NaN    NaN   NaN  63.6   NaN   NaN

# %% [markdown]
# **Cross Tabs**

# %%
# pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
